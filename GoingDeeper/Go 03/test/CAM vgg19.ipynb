# %%
# 라이브러리 불러오기
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

import copy
import cv2
from PIL import Image

import os
import json
import random

import pandas as pd

print('완료')
# Out:
# 완료

# %%
# gpu 확인하기
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# 데이터 불러오기
# 최초 수행시에는 다운로드가 진행됩니다. 오래 걸릴 수 있으니 유의해 주세요.  
(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs',
    split=['train', 'test'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)
print('완료')
# Out:
# 완료

# %%
# 데이터셋의 메타 정보인 df_info를 조회해 features가 어떻게 구성되어 있는지 확인하기
ds_info.features
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#     'image/filename': Text(shape=(), dtype=tf.string),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=120),
#     'objects': Sequence({
#         'bbox': BBoxFeature(shape=(4,), dtype=tf.float32),
#     }),
# })

# %%
# 데이터셋의 클래스 수
num_classes = ds_info.features["label"].num_classes
print(num_classes)
# Out:
# 120

# %%
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

# VGG19 모델 불러오기
base_model = VGG19(
    include_top=False,         # Fully Connected Layer 제거
    weights='imagenet',        # ImageNet 사전 학습된 가중치 사용
    input_shape=(224, 224, 3)  # 입력 이미지 크기
)

# Global Average Pooling 추가
x = base_model.output
x = GlobalAveragePooling2D()(x)
outputs = Dense(num_classes, activation='softmax', use_bias=False)(x)

# 새로운 모델 생성
vgg19_model = Model(inputs=base_model.input, outputs=outputs)

# 모델 요약 출력 (필요 시)
vgg19_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               61440
# =================================================================
# Total params: 20,085,824
# Trainable params: 20,085,824
# Non-trainable params: 0
# _________________________________________________________________

# %%
def normalize_and_resize_img(image, label):
    # 이미지 데이터 정규화 및 크기 조정
    image = tf.image.resize(image, [224, 224])  # 이미지를 224x224 크기로 조정
    image = tf.cast(image, tf.float32) / 255.0  # uint8(0~255) 데이터를 float32(0~1)로 정규화
    return image, label  # 정규화된 이미지와 레이블을 반환

print("완료")
# Out:
# 완료

# %%
def onehot(image, label):
    label = tf.one_hot(label, num_classes)
    return image, label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    # 데이터셋에 정규화 및 배치 처리 적용
    ds = ds.map(
        normalize_and_resize_img,  # 데이터셋의 각 이미지를 정규화 및 크기 조정
        num_parallel_calls=2       # 병렬로 데이터를 2개의 코어에서 처리
    )
    ds = ds.map(
        onehot,
        num_parallel_calls=2
    )
    ds = ds.batch(batch_size)      # 지정된 크기만큼 배치로 묶음
    
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)  # 데이터 로드와 학습을 병렬 처리하여 성능 최적화
    return ds  # 처리된 데이터셋 반환

print('완료')
# Out:
# 완료

# %%
# 데이터셋에 전처리와 배치처리를 적용합니다.
ds_train_norm = apply_normalize_on_dataset(ds_train)
ds_val_norm = apply_normalize_on_dataset(ds_test)

# 구성된 배치의 모양을 확인해 봅니다. 
for input in ds_train_norm.take(1):
    image, label = input
    print(image.shape)
    print(label.shape)
# Out:
# (16, 224, 224, 3)
# (16, 120)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(os.getenv('HOME')+'/class_activation_map/vgg19_model_checkpoint.h5', verbose=1, save_best_only=True, mode='min', save_weights_only=True)

# %%
# 학습하기
vgg19_model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    metrics=['accuracy'],
)

history_vgg19_model = vgg19_model.fit(
    ds_train_norm,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=50,
    validation_data=ds_val_norm,
    verbose=1,
    use_multiprocessing=True,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/50
# 750/750 [==============================] - 238s 304ms/step - loss: 4.7922 - accuracy: 0.0077 - val_loss: 4.7872 - val_accuracy: 0.0120
#
# Epoch 00001: val_loss improved from inf to 4.78724, saving model to /aiffel/class_activation_map/vgg19_model_checkpoint.h5
# Epoch 2/50
# 750/750 [==============================] - 228s 304ms/step - loss: 4.7864 - accuracy: 0.0111 - val_loss: 4.7803 - val_accuracy: 0.0099
#
# Epoch 00002: val_loss improved from 4.78724 to 4.78031, saving model to /aiffel/class_activation_map/vgg19_model_checkpoint.h5
# Epoch 3/50
# 750/750 [==============================] - 229s 305ms/step - loss: 4.5758 - accuracy: 0.0348 - val_loss: 4.2704 - val_accuracy: 0.0815
#
# Epoch 00003: val_loss improved from 4.78031 to 4.27041, saving model to /aiffel/class_activation_map/vgg19_model_checkpoint.h5
# Epoch 4/50
# 750/750 [==============================] - 229s 305ms/step - loss: 3.2504 - accuracy: 0.1953 - val_loss: 2.5047 - val_accuracy: 0.3586
#
# Epoch 00004: val_loss improved from 4.27041 to 2.50473, saving model to /aiffel/class_activation_map/vgg19_model_checkpoint.h5
# Epoch 5/50
# 750/750 [==============================] - 229s 306ms/step - loss: 2.2055 - accuracy: 0.3986 - val_loss: 2.1122 - val_accuracy: 0.4338
#
# Epoch 00005: val_loss improved from 2.50473 to 2.11220, saving model to /aiffel/class_activation_map/vgg19_model_checkpoint.h5
# Epoch 6/50
# 750/750 [==============================] - 229s 306ms/step - loss: 1.6039 - accuracy: 0.5443 - val_loss: 1.9083 - val_accuracy: 0.4710
#
# Epoch 00006: val_loss improved from 2.11220 to 1.90830, saving model to /aiffel/class_activation_map/vgg19_model_checkpoint.h5
# Epoch 7/50
# 750/750 [==============================] - 229s 306ms/step - loss: 1.2046 - accuracy: 0.6452 - val_loss: 1.7511 - val_accuracy: 0.5336
#
# Epoch 00007: val_loss improved from 1.90830 to 1.75108, saving model to /aiffel/class_activation_map/vgg19_model_checkpoint.h5
# Epoch 8/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.9301 - accuracy: 0.7176 - val_loss: 2.2187 - val_accuracy: 0.4268
#
# Epoch 00008: val_loss did not improve from 1.75108
# Epoch 9/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.6673 - accuracy: 0.7951 - val_loss: 1.9349 - val_accuracy: 0.5466
#
# Epoch 00009: val_loss did not improve from 1.75108
# Epoch 10/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.5157 - accuracy: 0.8433 - val_loss: 2.1372 - val_accuracy: 0.5017
#
# Epoch 00010: val_loss did not improve from 1.75108
# Epoch 11/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.3838 - accuracy: 0.8819 - val_loss: 2.0796 - val_accuracy: 0.5015
#
# Epoch 00011: val_loss did not improve from 1.75108
# Epoch 12/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.2896 - accuracy: 0.9136 - val_loss: 2.3802 - val_accuracy: 0.5319
#
# Epoch 00012: val_loss did not improve from 1.75108
# Epoch 13/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.2662 - accuracy: 0.9215 - val_loss: 2.2419 - val_accuracy: 0.5442
#
# Epoch 00013: val_loss did not improve from 1.75108
# Epoch 14/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.1854 - accuracy: 0.9447 - val_loss: 2.4139 - val_accuracy: 0.5743
#
# Epoch 00014: val_loss did not improve from 1.75108
# Epoch 15/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.1636 - accuracy: 0.9498 - val_loss: 2.2298 - val_accuracy: 0.5770
#
# Epoch 00015: val_loss did not improve from 1.75108
# Epoch 16/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.1346 - accuracy: 0.9608 - val_loss: 2.5222 - val_accuracy: 0.5372
# 750/750 [==============================] - 229s 305ms/step - loss: 0.1195 - accuracy: 0.9653 - val_loss: 2.1426 - val_accuracy: 0.5845
#
# Epoch 00017: val_loss did not improve from 1.75108
# Epoch 18/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0971 - accuracy: 0.9732 - val_loss: 2.3593 - val_accuracy: 0.5758
#
# Epoch 00018: val_loss did not improve from 1.75108
# Epoch 19/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0795 - accuracy: 0.9763 - val_loss: 2.2413 - val_accuracy: 0.5693
#
# Epoch 00019: val_loss did not improve from 1.75108
# Epoch 20/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0610 - accuracy: 0.9837 - val_loss: 2.2837 - val_accuracy: 0.5724
#
# Epoch 00020: val_loss did not improve from 1.75108
# Epoch 21/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0907 - accuracy: 0.9766 - val_loss: 2.3771 - val_accuracy: 0.5821
#
# Epoch 00021: val_loss did not improve from 1.75108
# Epoch 22/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0426 - accuracy: 0.9872 - val_loss: 2.6142 - val_accuracy: 0.5856
#
# Epoch 00022: val_loss did not improve from 1.75108
# Epoch 23/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0679 - accuracy: 0.9799 - val_loss: 2.5035 - val_accuracy: 0.5134
#
# Epoch 00023: val_loss did not improve from 1.75108
# Epoch 24/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0444 - accuracy: 0.9890 - val_loss: 2.6387 - val_accuracy: 0.5723
#
# Epoch 00024: val_loss did not improve from 1.75108
# Epoch 25/50
# 750/750 [==============================] - 268s 358ms/step - loss: 0.0312 - accuracy: 0.9924 - val_loss: 2.6392 - val_accuracy: 0.6122
#
# Epoch 00025: val_loss did not improve from 1.75108
# Epoch 26/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0348 - accuracy: 0.9908 - val_loss: 2.3018 - val_accuracy: 0.6090
#
# Epoch 00026: val_loss did not improve from 1.75108
# Epoch 27/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0248 - accuracy: 0.9923 - val_loss: 2.7697 - val_accuracy: 0.5919
#
# Epoch 00027: val_loss did not improve from 1.75108
# Epoch 28/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0200 - accuracy: 0.9951 - val_loss: 2.6125 - val_accuracy: 0.5962
#
# Epoch 00028: val_loss did not improve from 1.75108
# Epoch 29/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0347 - accuracy: 0.9884 - val_loss: 2.7156 - val_accuracy: 0.5823
#
# Epoch 00029: val_loss did not improve from 1.75108
# Epoch 30/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0213 - accuracy: 0.9939 - val_loss: 2.6092 - val_accuracy: 0.5991
#
# Epoch 00030: val_loss did not improve from 1.75108
# Epoch 31/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0356 - accuracy: 0.9896 - val_loss: 2.7589 - val_accuracy: 0.5752
#
# Epoch 00031: val_loss did not improve from 1.75108
# Epoch 32/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0368 - accuracy: 0.9893 - val_loss: 2.4411 - val_accuracy: 0.5918
#
# Epoch 00032: val_loss did not improve from 1.75108
# Epoch 33/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0316 - accuracy: 0.9910 - val_loss: 2.6029 - val_accuracy: 0.5963
#
# Epoch 00033: val_loss did not improve from 1.75108
# Epoch 34/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0266 - accuracy: 0.9918 - val_loss: 2.4906 - val_accuracy: 0.6104
#
# Epoch 00034: val_loss did not improve from 1.75108
# Epoch 35/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 2.4185 - val_accuracy: 0.6194
#
# Epoch 00035: val_loss did not improve from 1.75108
# Epoch 36/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0086 - accuracy: 0.9966 - val_loss: 2.5447 - val_accuracy: 0.6098
#
# Epoch 00036: val_loss did not improve from 1.75108
# Epoch 37/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0058 - accuracy: 0.9973 - val_loss: 2.4453 - val_accuracy: 0.6196
#
# Epoch 00037: val_loss did not improve from 1.75108
# Epoch 38/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0050 - accuracy: 0.9971 - val_loss: 2.3668 - val_accuracy: 0.6209
#
# Epoch 00038: val_loss did not improve from 1.75108
# Epoch 39/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0048 - accuracy: 0.9970 - val_loss: 2.3766 - val_accuracy: 0.6273
#
# Epoch 00039: val_loss did not improve from 1.75108
# Epoch 40/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0040 - accuracy: 0.9972 - val_loss: 2.5145 - val_accuracy: 0.6314
#
# Epoch 00040: val_loss did not improve from 1.75108
# Epoch 41/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0038 - accuracy: 0.9972 - val_loss: 2.6779 - val_accuracy: 0.6311
#
# Epoch 00041: val_loss did not improve from 1.75108
# Epoch 42/50
# 750/750 [==============================] - 269s 358ms/step - loss: 0.0037 - accuracy: 0.9970 - val_loss: 2.6965 - val_accuracy: 0.6330
#
# Epoch 00042: val_loss did not improve from 1.75108
# Epoch 43/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0036 - accuracy: 0.9972 - val_loss: 2.7062 - val_accuracy: 0.6344
#
# Epoch 00043: val_loss did not improve from 1.75108
# Epoch 44/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0035 - accuracy: 0.9971 - val_loss: 2.6337 - val_accuracy: 0.6346
#
# Epoch 00044: val_loss did not improve from 1.75108
# Epoch 45/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0034 - accuracy: 0.9972 - val_loss: 2.5273 - val_accuracy: 0.6344
#
# Epoch 00045: val_loss did not improve from 1.75108
# Epoch 46/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0032 - accuracy: 0.9972 - val_loss: 2.4681 - val_accuracy: 0.6327
#
# Epoch 00046: val_loss did not improve from 1.75108
# Epoch 47/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0030 - accuracy: 0.9974 - val_loss: 2.5088 - val_accuracy: 0.6334
#
# Epoch 00047: val_loss did not improve from 1.75108
# Epoch 48/50
# 750/750 [==============================] - 229s 306ms/step - loss: 0.0030 - accuracy: 0.9973 - val_loss: 2.5711 - val_accuracy: 0.6328
#
# Epoch 00048: val_loss did not improve from 1.75108
# Epoch 49/50
# 750/750 [==============================] - 228s 303ms/step - loss: 0.0029 - accuracy: 0.9973 - val_loss: 2.6804 - val_accuracy: 0.6340
#
# Epoch 00049: val_loss did not improve from 1.75108
# Epoch 50/50
# 750/750 [==============================] - 229s 305ms/step - loss: 0.0029 - accuracy: 0.9973 - val_loss: 2.6865 - val_accuracy: 0.6336
#
# Epoch 00050: val_loss did not improve from 1.75108

# %%
vgg19_model.save_weights(os.getenv('HOME')+'/class_activation_map/vgg19_model_weights.h5')

# %%
vgg19_model.save(os.getenv('HOME')+'/class_activation_map/vgg19_model.keras')

# %%
with open('history/history_vgg19_model.json', 'w') as f:
    pd.DataFrame(history_vgg19_model.history).to_json(f)

# %%
## 모델 결과 시각화
plt.figure(figsize=(12,10))
plt.subplot(2,1,1)
plt.plot(history_vgg19_model.history['accuracy'], 'r', label="train_acc")
plt.plot(history_vgg19_model.history['val_accuracy'], 'b', label="valid_acc")
plt.title('vgg19_model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(2,1,2)
plt.plot(history_vgg19_model.history['loss'], 'r', label="train_loss")
plt.plot(history_vgg19_model.history['val_loss'], 'b', label="valid_loss")
plt.title('vgg19_model loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
val_acc_loss_dict = {'No Augmentation': history_vgg19_model.history['val_accuracy'],
                     'No Augmentation': history_vgg19_model.history['val_loss']}
df1 = pd.DataFrame(val_acc_loss_dict)
df1
# Out:
#     No Augmentation
# 0          4.787241
# 1          4.780313
# 2          4.270409
# 3          2.504729
# 4          2.112202
# 5          1.908300
# 6          1.751076
# 7          2.218681
# 8          1.934916
# 9          2.137153
# 10         2.079600
# 11         2.380231
# 12         2.241917
# 13         2.413934
# 14         2.229769
# 15         2.522225
# 16         2.142569
# 17         2.359291
# 18         2.241292
# 19         2.283660
# 20         2.377121
# 21         2.614248
# 22         2.503473
# 23         2.638739
# 24         2.639206
# 25         2.301841
# 26         2.769669
# 27         2.612502
# 28         2.715568
# 29         2.609167
# 30         2.758943
# 31         2.441102
# 32         2.602903
# 33         2.490614
# 34         2.418487
# 35         2.544661
# 36         2.445282
# 37         2.366779
# 38         2.376601
# 39         2.514469
# 40         2.677860
# 41         2.696461
# 42         2.706156
# 43         2.633662
# 44         2.527276
# 45         2.468057
# 46         2.508815
# 47         2.571148
# 48         2.680418
# 49         2.686481
